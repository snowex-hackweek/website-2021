# %% [markdown]
# # Thermal IR Tutorial 1: Comparing different raster datasets
#
# **At the conclusion of this tutorial, you will be able to:**
# - Access and visualize airborne and satellite thermal infrared imagery
# - Scale imagery of different spatial resolutions for comparison
#
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import rioxarray as xr

# %%
ds = xr.open_rasterio('data/AST_L1T_00302082020180748_20200209065849_17218_T.tif')

# %%
ds
# Out:
# <xarray.DataArray (band: 3, y: 817, x: 927)>
# [2272077 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 1 2 3
#   * x            (x) float64 6.998e+05 6.998e+05 ... 7.83e+05 7.831e+05
#   * y            (y) float64 4.357e+06 4.356e+06 ... 4.283e+06 4.283e+06
#     spatial_ref  int64 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0

# %% [markdown]
# ASTER product documentation showing:
# - which bands/wavelengths we're looking at
# - how to convert from DN to Radiance
# - how to convert from Radiance to Tb

# %%
plt.figure(figsize=(20,20))
ds.sel(band=1).plot(vmin=130,vmax=170)

# %% [markdown]
# At the end, export two netcdf or csv files each containing:
#  - geopandas/geojson geometry of the 3x3 ASTER pixels that overlaps our snowpit 2S10 study site?
#  - timeseries of temperature within that ASTER pixel footprint
#    - for the ASTER image, this will just be one point in time with the value of that pixel, or maybe a 3x3 pixel window
#    - for the airborne images, theis will be several images in time wih the mean values of the aster pixels?
#
# Those files will be read into the next notebook to compare against the ground data
